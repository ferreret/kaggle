# %%
import pandas as pd

# %%
reviews = pd.read_csv('./data/winemag-data-130k-v2.csv', index_col=0)
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# region_1 and region_2 are pretty uninformative names for locale columns in the dataset. Create a copy of reviews with these columns renamed to region and locale, respectively.

# %%
renamed = reviews.rename(columns={'region_1': 'region', "region_2": "locale"})
renamed.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                 region             locale         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# Set the index name in the dataset to wines.

# %%
reindexed = reviews.rename_axis("wines", axis="rows")
reindexed
# Out:
#          country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# wines
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
gaming_products = pd.read_csv('./data/gaming.csv', index_col=0)
gaming_products.head()
# Out:
#                                                         category  \
# name
# BOOMco Halo Covenant Needler Blaster                Toys & Games
# Raspberry PI 3 Model B 1.2GHz 64-bit quad-core ...   Electronics
# CanaKit 5V 2.5A Raspberry Pi 3 Power Supply / A...   Electronics
# Panasonic K-KJ17MCA4BA Advanced Individual Cell...   Electronics
# Mayflash GameCube Controller Adapter for Wii U ...   Electronics
#
#                                                                                           amazon_link  \
# name
# BOOMco Halo Covenant Needler Blaster                https://www.amazon.com/BOOMco-Halo-Covenant-Ne...
# Raspberry PI 3 Model B 1.2GHz 64-bit quad-core ...  https://www.amazon.com/Raspberry-Model-A1-2GHz...
# CanaKit 5V 2.5A Raspberry Pi 3 Power Supply / A...  https://www.amazon.com/CanaKit-Raspberry-Suppl...
# Panasonic K-KJ17MCA4BA Advanced Individual Cell...  https://www.amazon.com/Panasonic-Advanced-Indi...
# ...

# %%
movie_products = pd.read_csv('./data/movies.csv', index_col=0)
movie_products.head()
# Out:
#                                                        category  \
# name
# Marvel Cinematic Universe: Phase One - Avengers...  Movies & TV
# On Stranger Tides                                         Books
# Superintelligence: Paths, Dangers, Strategies             Books
# The Secret History of Star Wars                           Books
# 2D Glasses 4 Pack - Turns 3D movies back into 2...  Electronics
#
#                                                                                           amazon_link  \
# name
# Marvel Cinematic Universe: Phase One - Avengers...  https://www.amazon.com/Marvel-Cinematic-Univer...
# On Stranger Tides                                   https://www.amazon.com/Stranger-Tides-Tim-Powe...
# Superintelligence: Paths, Dangers, Strategies       https://www.amazon.com/Superintelligence-Dange...
# The Secret History of Star Wars                     https://www.amazon.com/Secret-History-Star-War...
# ...

# %%
combined_products = pd.concat([gaming_products, movie_products])
combined_products.head()
# Out:
#                                                         category  \
# name
# BOOMco Halo Covenant Needler Blaster                Toys & Games
# Raspberry PI 3 Model B 1.2GHz 64-bit quad-core ...   Electronics
# CanaKit 5V 2.5A Raspberry Pi 3 Power Supply / A...   Electronics
# Panasonic K-KJ17MCA4BA Advanced Individual Cell...   Electronics
# Mayflash GameCube Controller Adapter for Wii U ...   Electronics
#
#                                                                                           amazon_link  \
# name
# BOOMco Halo Covenant Needler Blaster                https://www.amazon.com/BOOMco-Halo-Covenant-Ne...
# Raspberry PI 3 Model B 1.2GHz 64-bit quad-core ...  https://www.amazon.com/Raspberry-Model-A1-2GHz...
# CanaKit 5V 2.5A Raspberry Pi 3 Power Supply / A...  https://www.amazon.com/CanaKit-Raspberry-Suppl...
# Panasonic K-KJ17MCA4BA Advanced Individual Cell...  https://www.amazon.com/Panasonic-Advanced-Indi...
# ...

# %% [markdown]
# The Powerlifting Database dataset on Kaggle includes one CSV table for powerlifting meets and a separate one for powerlifting competitors. Run the cell below to load these datasets into dataframes:

# %%
powerlifting_meets = pd.read_csv("./data/meets.csv")
powerlifting_competitors = pd.read_csv("./data/openpowerlifting.csv")

# %%
powerlifting_meets.head()
# Out:
#    MeetID        MeetPath Federation        Date MeetCountry MeetState  \
# 0       0  365strong/1601  365Strong  2016-10-29         USA        NC
# 1       1  365strong/1602  365Strong  2016-11-19         USA        MO
# 2       2  365strong/1603  365Strong  2016-07-09         USA        NC
# 3       3  365strong/1604  365Strong  2016-06-11         USA        SC
# 4       4  365strong/1605  365Strong  2016-04-10         USA        SC
#
#     MeetTown                                           MeetName
# 0  Charlotte  2016 Junior & Senior National Powerlifting Cha...
# 1      Ozark                  Thanksgiving Powerlifting Classic
# 2  Charlotte                             Charlotte Europa Games
# 3  Rock Hill                   Carolina Cup Push Pull Challenge
# 4  Rock Hill                              Eastern USA Challenge

# %%
powerlifting_competitors.head()
# Out:
#    MeetID              Name Sex   Equipment   Age     Division  BodyweightKg  \
# 0       0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49         59.60
# 1       0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44         58.51
# 2       0       Dawn Bogart   F  Single-ply  42.0  Open Senior         58.51
# 3       0       Dawn Bogart   F         Raw  42.0  Open Senior         58.51
# 4       0      Destiny Dula   F         Raw  18.0   Teen 18-19         63.68
#
#   WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  BestBenchKg  Deadlift4Kg  \
# 0            60       NaN        47.63       NaN        20.41          NaN
# 1            60       NaN       142.88       NaN        95.25          NaN
# 2            60       NaN       142.88       NaN        95.25          NaN
# 3            60       NaN          NaN       NaN        95.25          NaN
# 4          67.5       NaN          NaN       NaN        31.75          NaN
#
#    BestDeadliftKg  TotalKg Place   Wilks
# ...

# %%
powerlifting_combined = powerlifting_meets.set_index("MeetID").join(powerlifting_competitors.set_index("MeetID"))
powerlifting_combined.head()
# Out:
#               MeetPath Federation        Date MeetCountry MeetState  \
# MeetID
# 0       365strong/1601  365Strong  2016-10-29         USA        NC
# 0       365strong/1601  365Strong  2016-10-29         USA        NC
# 0       365strong/1601  365Strong  2016-10-29         USA        NC
# 0       365strong/1601  365Strong  2016-10-29         USA        NC
# 0       365strong/1601  365Strong  2016-10-29         USA        NC
#
#          MeetTown                                           MeetName  \
# MeetID
# 0       Charlotte  2016 Junior & Senior National Powerlifting Cha...
# 0       Charlotte  2016 Junior & Senior National Powerlifting Cha...
# 0       Charlotte  2016 Junior & Senior National Powerlifting Cha...
# 0       Charlotte  2016 Junior & Senior National Powerlifting Cha...
# 0       Charlotte  2016 Junior & Senior National Powerlifting Cha...
#
#                     Name Sex   Equipment  ...  WeightClassKg Squat4Kg  \
# MeetID                                    ...
# ...
